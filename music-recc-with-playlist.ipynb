# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neighbors import NearestNeighbors

# %%
df = pd.read_csv('dataset.csv')
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
#  16  liveness          114000 non-null  float64
#  17  valence           114000 non-null  float64
#  18  tempo             114000 non-null  float64
#  19  time_signature    114000 non-null  int64
#  20  track_genre       114000 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(5)
# memory usage: 17.5+ MB
# (114000, 21)

# %%
duplicated_rows = df['track_id'].duplicated().sum()

if duplicated_rows != 0:
    df = df.drop_duplicates(subset=['track_id'])
    undroped_nrows, ncols = df.shape
    dropped_rows = duplicated_rows
    print(f'There is a total of {dropped_rows} rows dropped based on "track_id')
    
print(f'Final dataframe shape: {df.shape}')
# Out:
# There is a total of 24259 rows dropped based on "track_id
# Final dataframe shape: (89741, 21)

# %%
total_rows_with_missing_values = (df.isnull().any(axis=1)).sum()
print(f'Total number of rows with missing values: {total_rows_with_missing_values}')
# Out:
# Total number of rows with missing values: 1

# %%
index_to_drop = df[df.isnull().any(axis=1)].index
df.drop(index_to_drop, inplace=True)
print(f'Rows with missing values dropped. Updated dataframe shape: {df.shape}')
# Out:
# Rows with missing values dropped. Updated dataframe shape: (89740, 21)

# %%
df = df[(df['duration_ms']<=600000) & (df['duration_ms']>=60000)]
print(f'The dataframe now has {df.shape[0]} rows')
# Out:
# The dataframe now has 88419 rows

# %%
df = df[df['popularity']>=10]
print(f'The dataframe now has {df.shape[0]} rows')
# Out:
# The dataframe now has 74778 rows

# %%
df = df.drop(['time_signature', 'key'], axis=1)

# %%
output_file = 'Project_data.csv'
df.to_csv(output_file, index=False)

# %%
df.shape
# Out:
# (74778, 19)

# %%
features = ['danceability', 'energy', 'valence', 'tempo', 'acousticness', 'liveness', 'speechiness', 'instrumentalness']
scaler = MinMaxScaler()
normalized_features = scaler.fit_transform(df[features])
pd.DataFrame(normalized_features, columns=features).head()
# Out:
#    danceability  energy   valence     tempo  acousticness  liveness  \
# 0      0.686294  0.4610  0.718593  0.361245      0.032329    0.3580
# 1      0.426396  0.1660  0.268342  0.318397      0.927711    0.1010
# 2      0.444670  0.3590  0.120603  0.313643      0.210843    0.1170
# 3      0.270051  0.0596  0.143719  0.746758      0.908635    0.1320
# 4      0.627411  0.4430  0.167839  0.492863      0.470884    0.0829
#
#    speechiness  instrumentalness
# 0     0.148494          0.000001
# 1     0.079232          0.000006
# 2     0.057840          0.000000
# 3     0.037695          0.000071
# 4     0.054621          0.000000

# %%
df['track_id'] = df.index
df['artists'] = df['artists'].astype(str)
df['album_name'] = df['album_name'].astype(str)
df['track_name'] = df['track_name'].astype(str)
df['track_genre'] = df['track_genre'].astype(str)

# %%
preprocessed_file_path = 'preprocessed_dataset.csv'
df.to_csv(preprocessed_file_path, index=False)

# %%
from sklearn.neighbors import NearestNeighbors

k = 5
knn_model = NearestNeighbors(n_neighbors=k, metric='cosine')
knn_model.fit(normalized_features)

def recommend_songs(song_index, num_recommendations=5):
    distances, indices = knn_model.kneighbors([normalized_features[song_index]], n_neighbors=num_recommendations + 1)
    recommendations = df.iloc[indices[0][1:]]
    return recommendations[['track_name', 'artists', 'album_name', 'track_genre', 'popularity']]

sample_song_index = 21000

print(df.iloc[sample_song_index])
recommended_songs = recommend_songs(sample_song_index)
recommended_songs
# Out:
# Unnamed: 0              28137
# track_id                28137
# artists             GG Magree
# album_name          Deja Reve
# track_name          Deja Reve
# popularity                 54
# duration_ms            168073
# explicit                False
# danceability            0.611
# energy                  0.618
# loudness               -6.573
# mode                        0
# speechiness            0.0655
# acousticness           0.0029
# instrumentalness     0.000757
# liveness                 0.24
# valence                 0.515
# tempo                  99.999
# track_genre               dub
# Name: 28137, dtype: object
#               track_name                 artists  \
# 25565      Kylie - Remix     Akcent;Midi Culture
# 65806        DALLA DALLA                    ITZY
# 23110          Pumped Up               Klingande
# 66308  Wheels on the Bus           Hip Hop Harry
# 13200        House Party  Aaron Smith;Malik Hart
#
#                           album_name    track_genre  popularity
# 25565                  Kylie (Remix)          disco          46
# 65806                 IT'z Different          k-pop          68
# 23110                      The Album     deep-house          58
# 66308  Nursery Rhymes (Bonus Tracks)           kids          14
# 13200                    House Party  chicago-house          21

# %%
def recommend_by_song_name(song_name, num_recommendations=5):
    matches = df[df['track_name'].str.contains(song_name, case=False, na=False)]
    if matches.empty:
        return f"No matches found for song name: {song_name}"
    print(matches)
    song_index = matches.index[0]
    print(f"Recommendations based on: {matches.iloc[0]['track_name']} by {matches.iloc[0]['artists']}")
    return recommend_songs(song_index, num_recommendations)

song_name_input = "Rap God"

recommendations = recommend_by_song_name(song_name_input)
recommendations
# Out:
#        Unnamed: 0  track_id artists                         album_name  \
# 51614       51614     51614  Eminem  The Marshall Mathers LP2 (Deluxe)
#
#       track_name  popularity  duration_ms  explicit  danceability  energy  \
# 51614    Rap God          78       363521      True         0.708   0.843
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 51614     -2.66     1        0.314         0.397               0.0     0.799
#
#        valence   tempo track_genre
# 51614    0.625  148.14     hip-hop
# Recommendations based on: Rap God by Eminem
#                          track_name              artists   album_name  \
# 75096                     Returning        Tony O'Connor      Mariner
# 101204                       Sonder        Modal Colours       Sonder
# 11993   Mother Of God, Here I Stand  John Tavener;Voces8          Lux
# 101765                  Perspective       Jorin Williams  Perspective
# 101355                  Amado Nervo             Sayulita  Amado Nervo
#
#        track_genre  popularity
# 75096      new-age          32
# 101204       sleep          65
# 11993      british          27
# 101765       sleep          60
# 101355       sleep          62

# %%
def recommend_by_track_id(track_id, num_recommendations=5):
    if track_id not in df.index:
        return f"No matches found for track ID: {track_id}"
    
    song_index = track_id
    print(f"Recommendations based on: {df.loc[song_index, 'track_name']} by {df.loc[song_index, 'artists']}")
     
    distances, indices = knn_model.kneighbors([normalized_features[song_index]], n_neighbors=num_recommendations + 1)
    recommendations = df.iloc[indices[0][1:]]
    
    return recommendations[['track_id', 'track_name', 'artists', 'album_name', 'track_genre', 'popularity']]

sample_track_id = 22
recommendations = recommend_by_track_id(sample_track_id)
print(recommendations)
# Out:
# Recommendations based on: Say Something by A Great Big World;Christina Aguilera
#         track_id              track_name  \
# 6              6           Say Something
# 164          164           Say Something
# 75079      75079  Reflections of Passion
# 55427      55427                    Ghar
# 113653    113653               Our Jesus
#
#                                      artists                   album_name  \
# 6       A Great Big World;Christina Aguilera  Is There Anybody Out There?
# 164     A Great Big World;Christina Aguilera                Say Something
# 75079                                  Yanni          The Essential Yanni
# 55427                         Bharat Chauhan                Ghar - Single
# 113653               Bethel Music;David Funk                       Simple
#
#         track_genre  popularity
# 6          acoustic          74
# 164        acoustic          58
# 75079       new-age          47
# 55427        indian          49
# 113653  world-music          50

# %%
def recommend_by_features(track_id, filter_by="genre", num_recommendations=5):
    if track_id not in df.index:
        return f"No matches found for track ID: {track_id}"
    
    song_index = track_id
    print(f"Recommendations based on: {df.loc[song_index, 'track_name']} by {df.loc[song_index, 'artists']}")
    
    selected_song = df.loc[track_id]
    filter_value = selected_song[filter_by]
    
    filtered_data = df[df[filter_by] == filter_value]

    if filtered_data.empty:
        return f"No songs found with the same {filter_by} as the selected song."
    
    filtered_indices = filtered_data.index
    filtered_features = normalized_features[filtered_indices]
    
    knn_model_filtered = NearestNeighbors(n_neighbors=num_recommendations + 1, metric="cosine")
    knn_model_filtered.fit(filtered_features)
    
    song_index_in_filtered = list(filtered_indices).index(track_id)
    distances, indices = knn_model_filtered.kneighbors([filtered_features[song_index_in_filtered]], n_neighbors=num_recommendations + 1)
    
    recommended_indices = [filtered_indices[i] for i in indices[0][1:]]
    recommendations = df.loc[recommended_indices]
    
    return recommendations[['track_id', 'track_name', 'artists', 'album_name', 'track_genre', 'popularity']]

sample_track_id = 4
recommendations = recommend_by_features(sample_track_id, filter_by="track_genre",num_recommendations=5)
print(recommendations)
# Out:
# Recommendations based on: Hold On by Chord Overstreet
#      track_id                            track_name               artists  \
# 896       896  Alone in the Dark Mansion of Madness            Harley Poe
# 341       341                        Tell The World       Eric Hutchinson
# 251       251                    Believe - Acoustic            John Adams
# 272       272                                Arcade  Andrew Foy;Renee Foy
# 613       613                          First & Last          Zack Tabudlo
#
#              album_name track_genre  popularity
# 896           Horrorful    acoustic          26
# 341        Pure Fiction    acoustic          58
# 251  Believe (Acoustic)    acoustic          57
# 272              Arcade    acoustic          37
# 613             Episode    acoustic          49

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import hstack, csr_matrix

# %%
df = pd.read_csv('preprocessed_dataset.csv')

df['artists'] = df['artists'].astype(str)
df['track_genre'] = df['track_genre'].astype(str)
df['track_name'] = df['track_name'].astype(str)

# %%
numerical_features = ['danceability', 'energy', 'valence', 'tempo', 'acousticness', 'liveness', 'speechiness', 'instrumentalness']
scaler = MinMaxScaler()
normalized_numerical = scaler.fit_transform(df[numerical_features])
numerical_sparse = csr_matrix(normalized_numerical)

# %%
genre_vectorizer = TfidfVectorizer()
genre_features = genre_vectorizer.fit_transform(df['track_genre'])

artist_vectorizer = TfidfVectorizer()
artist_features = artist_vectorizer.fit_transform(df['artists'])

# %%
num_w, gen_w, art_w = 1.0, 1.5, 0.5
combined_features = hstack([
    numerical_sparse * num_w,
    genre_features * gen_w,
    artist_features * art_w
])

# %%
knn_model = NearestNeighbors(n_neighbors=51, metric='cosine')
knn_model.fit(combined_features)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=51)

# %%
def content_based_recommend(song_index, top_n=50):
    if song_index >= len(df):
        return f"Index {song_index} out of bounds."
    
    distances, indices = knn_model.kneighbors(combined_features[song_index], n_neighbors=top_n + 1)
    recommended_indices = indices[0][1:]
    return df.iloc[recommended_indices][['track_name', 'artists', 'track_genre', 'popularity']]

# %%
def recommend_by_song_name(song_name, top_n=50):
    matches = df[df['track_name'].str.contains(song_name, case=False, na=False)]
    if matches.empty:
        return f"No song found with name similar to '{song_name}'"
    
    song_index = matches.index[0]
    print(f"\nRecommendations based on: '{df.loc[song_index, 'track_name']}' by {df.loc[song_index, 'artists']}")
    return content_based_recommend(song_index, top_n)

# %%
song_index = 38155  
print(df.loc[song_index, ['track_name', 'artists']])
print(content_based_recommend(song_index, top_n=50))

print(recommend_by_song_name("Rap God", top_n=50))
# Out:
# track_name               Nanchaku
# artists       Seedhe Maut;MC STAN
# Name: 38155, dtype: object
#                                              track_name  \
# 38026                                    Astaghfirullah
# 37877                                      Ek Din Pyaar
# 37705                                        Shana Bann
# 37706                                    Basti Ka Hasti
# 38119                                          Tadipaar
# 38086                                     Kahan Par Hai
# 37780                                             Bitch
# 38098                                     Chalo Chalein
# 38096                                        SICKO MODE
# 37753                                         Freestyle
# 38065                                        Positivity
# 37948                                         Lil Bunty
# 37881                                         They Know
# 37974                                      KR L$DA SIGN
# 37785                                              GOAT
# 37820                                   Broke Is A Joke
# 37954                                       Majhail 1.0
# 37698                      Love Sick (feat. AR Paisley)
# 37782                                             Snake
# 37983                                  AGAINST ALL ODDS
# 37754  Two Two Two (From "Kaathuvaakula Rendu Kaadhal")
# 38123                                    Jatt te Jawani
# 37794                            Astronaut In The Ocean
# 37774                                      Pata Chalgea
# 37896                                       Chal Bombay
# 38103                                            Pinnak
# 37645                                        Cold Hours
# 38105                                            Mirchi
# 37828                                           Me & Me
# 37989                                     Ud-daa Punjab
# 38085                                      Badmos Chora
# 38074                                       Two Two Two
# 38100                                          CHUSAMBA
# 37781                                             Oouuu
# 37743                                       Paani Paani
# 37992                            Bad Boy (From "Saaho")
# 37979                                    Puff Puff Pass
# 37942                                       Black Matte
# 38147                           IDGAF (feat. Morrisson)
# 37767                                       Fuck Em All
# 37807                                     Old Town Road
# 37700                                           Gangsta
# 37879                   Halamithi Habibo (From "Beast")
# 38094                                          Die Hard
# 37969                                           HUMBLE.
# 38070                                 Nenjinile Rebirth
# 37898                                           Top Boy
# 38041                                       Most Wanted
# 37945                                          Untitled
# 37973                                        goosebumps
#
#                                                  artists track_genre  \
# 38026                                            MC STAN     hip-hop
# 37877                                            MC STAN     hip-hop
# 37705                                            MC STAN     hip-hop
# 37706                                            MC STAN     hip-hop
# 38119                                            MC STAN     hip-hop
# 38086                                            MC STAN     hip-hop
# 37780                                            MC STAN     hip-hop
# 38098                                 Ritviz;Seedhe Maut     hip-hop
# 38096                                       Travis Scott     hip-hop
# 37753                                      Jordan Sandhu     hip-hop
# 38065                                      Jordan Sandhu     hip-hop
# 37948                                              KR$NA     hip-hop
# 37881                                        Karan Aujla     hip-hop
# 37974                                      Emiway Bantai     hip-hop
# 37785                                   Sidhu Moose Wala     hip-hop
# 37820                                            MC STAN     hip-hop
# 37954                                      Jordan Sandhu     hip-hop
# 37698                        Sidhu Moose Wala;AR Paisley     hip-hop
# 37782                                            MC STAN     hip-hop
# 37983      AP Dhillon;Gurinder Gill;Gminxr;Shinda Kahlon     hip-hop
# 37754  Anirudh Ravichander;Sunidhi Chauhan;Sanjana Ka...     hip-hop
# 38123                       Dilpreet Dhillon;Karan Aujla     hip-hop
# 37794                                        Masked Wolf     hip-hop
# 37774                                         Imran Khan     hip-hop
# 37896                                             DIVINE     hip-hop
# 38103                                            SAMBATA     hip-hop
# 37645                                      aleemrk;Umair     hip-hop
# 38105                     DIVINE;MC Altaf;Stylo G;Phenom     hip-hop
# 37828                                               King     hip-hop
# 37989                        Vishal Dadlani;Amit Trivedi     hip-hop
# 38085                                          MC SQUARE     hip-hop
# 38074  Anirudh Ravichander;Sunidhi Chauhan;Sanjana Ka...     hip-hop
# 38100                                      Emiway Bantai     hip-hop
# 37781                                        Karan Aujla     hip-hop
# 37743                                Badshah;Aastha Gill     hip-hop
# 37992                                Badshah;Neeti Mohan     hip-hop
# 37979  Sultaan;Gavy Dhaliwal;Bhallwaan;Swapan Sekhon;...     hip-hop
# 37942                                Jaura Phagwara;Enzo     hip-hop
# 38147                         Sidhu Moose Wala;Morrisson     hip-hop
# 37767                      Sidhu Moose Wala;Sunny Malton     hip-hop
# 37807                                          Lil Nas X     hip-hop
# 37700                                     Karan Aujla;YG     hip-hop
# 37879                  Anirudh Ravichander;Jonita Gandhi     hip-hop
# 38094                 Kendrick Lamar;Blxst;Amanda Reifer     hip-hop
# 37969                                     Kendrick Lamar     hip-hop
# 38070                          Chris G.;Mc Sai;Sahi Siva     hip-hop
# 37898                                         AP Dhillon     hip-hop
# 38041                    AP Dhillon;Gurinder Gill;Gminxr     hip-hop
# 37945                                              KR$NA     hip-hop
# 37973                                       Travis Scott     hip-hop
#
#        popularity
# 38026          58
# 37877          62
# 37705          66
# 37706          67
# 38119          57
# 38086          57
# 37780          64
# 38098          59
# 38096          83
# 37753          68
# 38065          59
# 37948          59
# 37881          63
# 37974          59
# 37785          64
# 37820          62
# 37954          61
# 37698          70
# 37782          64
# 37983          62
# 37754          66
# 38123          57
# 37794          79
# 37774          64
# 37896          60
# 38103          56
# 37645          74
# 38105          57
# 37828          55
# 37989          59
# 38085          57
# 38074          57
# 38100          56
# 37781          67
# 37743          66
# 37992          61
# 37979          60
# 37942          60
# 38147          56
# 37767          64
# 37807          77
# 37700          72
# 37879          61
# 38094          82
# 37969          84
# 38070          59
# 37898          63
# 38041          60
# 37945          59
# 37973          84
#
# Recommendations based on: 'Rap God' by Eminem
#                                               track_name  \
# 37991              Venom - Music From The Motion Picture
# 37926                               Love The Way You Lie
# 37907                                         Not Afraid
# 37856                                               Stan
# 37860                                         Don't Look
# 37752                                     Bitch I'm Back
# 37873                        Godzilla (feat. Juice WRLD)
# 37848                                           Burberry
# 37693                                          Love Dose
# 37865                                             Dhakka
# 37770                                         Without Me
# 37956                                              Devil
# 37729                                           Gunehgar
# 37678                                  Bimbilikki Pilapi
# 37961                                              Aathi
# 37811                                            Majhail
# 37923                         Moosedrilla (feat. DIVINE)
# 38118                                      Pakkam Vanthu
# 38138                                           Vibe Hai
# 37810                                       Machayenge 4
# 37849                                        Malwa Block
# 37706                                     Basti Ka Hasti
# 38167           Lose Yourself - From "8 Mile" Soundtrack
# 38143                                           One Side
# 37829                                           Into You
# 37930                                     Tera Mera Viah
# 37841                                             Legend
# 37972                                           Superman
# 37837                                            Satisfy
# 38035                                         High Heels
# 37901                                            Ram Ram
# 37783  Oo Bolega Ya Oo Oo Bolega (From "Pushpa The Ri...
# 37984                                            Tu Meri
# 38117           Why This Kolaveri Di? - The Soup of Love
# 38054                                            Zingaat
# 37645                                         Cold Hours
# 37775           Why This Kolaveri Di? - The Soup of Love
# 37962                                                Sin
# 37952                                       Bambiha Bole
# 37993        Unfuckwithable (Bonus Track from Moosetape)
# 38081                                        Blood Talks
# 37755                                      Proper Patola
# 38071                                    What a Karavaad
# 37750                     MONTERO (Call Me By Your Name)
# 37996             Nee Paata Madhuram - The Touch of Love
# 37913                                             Chosen
# 38018                                          Bang Bang
# 38015                                          Issa Jatt
# 37954                                        Majhail 1.0
# 37776                                          Priceless
#
#                                                  artists track_genre  \
# 37991                                             Eminem     hip-hop
# 37926                                     Eminem;Rihanna     hip-hop
# 37907                                             Eminem     hip-hop
# 37856                                        Eminem;Dido     hip-hop
# 37860                                        Karan Aujla     hip-hop
# 37752                                   Sidhu Moose Wala     hip-hop
# 37873                                  Eminem;Juice WRLD     hip-hop
# 37848                                   Sidhu Moose Wala     hip-hop
# 37693                                  Yo Yo Honey Singh     hip-hop
# 37865                       Sidhu Moose Wala;Afsana Khan     hip-hop
# 37770                                             Eminem     hip-hop
# 37956                                   Sidhu Moose Wala     hip-hop
# 37729                                             DIVINE     hip-hop
# 37678   Anirudh Ravichander;Ramya Behra;Sahithi Chaganti     hip-hop
# 37961                 Anirudh Ravichander;Vishal Dadlani     hip-hop
# 37811              AP Dhillon;Gurinder Gill;Manni Sandhu     hip-hop
# 37923                            Sidhu Moose Wala;DIVINE     hip-hop
# 38118                 Anirudh Ravichander;Hiphop Tamizha     hip-hop
# 38138                   DIVINE;Aavrutti;D'Evil;Shah Rule     hip-hop
# 37810                                              KR$NA     hip-hop
# 37849                                   Sidhu Moose Wala     hip-hop
# 37706                                            MC STAN     hip-hop
# 38167                                             Eminem     hip-hop
# 38143                                             DIVINE     hip-hop
# 37829                            Tegi Pannu;Manni Sandhu     hip-hop
# 37930                                         Jass Manak     hip-hop
# 37841                                   Sidhu Moose Wala     hip-hop
# 37972                                    Eminem;Dina Rae     hip-hop
# 37837                    Sidhu Moose Wala;Shooter Kahlon     hip-hop
# 38035                        Jaz Dhami;Yo Yo Honey Singh     hip-hop
# 37901                                          MC SQUARE     hip-hop
# 37783                      Kanika Kapoor;Devi Sri Prasad     hip-hop
# 37984                                     Vishal Dadlani     hip-hop
# 38117                        Anirudh Ravichander;Dhanush     hip-hop
# 38054                                          Ajay-Atul     hip-hop
# 37645                                      aleemrk;Umair     hip-hop
# 37775                        Anirudh Ravichander;Dhanush     hip-hop
# 37962                                   Sidhu Moose Wala     hip-hop
# 37952                        Amrit Maan;Sidhu Moose Wala     hip-hop
# 37993                       Sidhu Moose Wala;Afsana Khan     hip-hop
# 38081                         Jordan Sandhu;Zikar Sandhu     hip-hop
# 37755                 Badshah;Diljit Dosanjh;Aastha Gill     hip-hop
# 38071                        Anirudh Ravichander;Dhanush     hip-hop
# 37750                                          Lil Nas X     hip-hop
# 37996  Anirudh Ravichander;Roop Kumar Rathod;Shreya G...     hip-hop
# 37913                      Sidhu Moose Wala;Sunny Malton     hip-hop
# 38018                            Benny Dayal;Neeti Mohan     hip-hop
# 38015                      Sidhu Moose Wala;Sunny Malton     hip-hop
# 37954                                      Jordan Sandhu     hip-hop
# 37776                           Bhalwaan;Signature By SB     hip-hop
#
#        popularity
# 37991          74
# 37926          83
# 37907          81
# 37856          85
# 37860          64
# 37752          66
# 37873          83
# 37848          63
# 37693          69
# 37865          62
# 37770          88
# 37956          59
# 37729          65
# 37678          71
# 37961          59
# 37811          66
# 37923          61
# 38118          56
# 38138          56
# 37810          61
# 37849          63
# 37706          67
# 38167          79
# 38143          56
# 37829          64
# 37930          61
# 37841          62
# 37972          86
# 37837          62
# 38035          59
# 37901          61
# 37783          64
# 37984          62
# 38117          57
# 38054          59
# 37645          74
# 37775          64
# 37962          60
# 37952          62
# 37993          59
# 38081          58
# 37755          68
# 38071          58
# 37750          83
# 37996          58
# 37913          60
# 38018          61
# 38015          59
# 37954          61
# 37776          65

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# %%
def get_spotify_track_id(sp, track_name, artist_name):
    main_artist = artist_name.split(";")[0].strip()
    query = f"track:{track_name} artist:{main_artist}"
    try:
        results = sp.search(q=query, type='track', limit=1)
        tracks = results.get('tracks', {}).get('items', [])
        if tracks:
            return tracks[0]['id']
    except spotipy.exceptions.SpotifyException as e:
        print(f"Spotify search failed for '{track_name}' by '{main_artist}': {e}")
    return None

# %%
def recommend_and_create_playlist(base_track_id, num_recommendations=50):
    recommendations = content_based_recommend(base_track_id, top_n=num_recommendations)
    if isinstance(recommendations, str):
        print(recommendations)
        return

    sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
        client_id='6ba6e7ce109a4f5386a882a14af9548e',
        client_secret='215a70945069468aa485345cfd0bc79b',
        redirect_uri='http://127.0.0.1:8000/callback',
        scope='playlist-modify-public playlist-modify-private'
    ))

    user_id = sp.current_user()['id']

    base_song_name = df.loc[base_track_id, 'track_name']
    playlist_name = f"Recommendations Based on {base_song_name}"
    playlist = sp.user_playlist_create(user=user_id, name=playlist_name, public=False)
    playlist_id = playlist['id']

    track_uris = []
    for _, row in recommendations.iterrows():
        track_id = get_spotify_track_id(sp, row['track_name'], row['artists'])
        if track_id:
            track_uris.append(f"spotify:track:{track_id}")

    if not track_uris:
        print("No valid Spotify tracks found.")
        return

    for i in range(0, len(track_uris), 100):
        sp.playlist_add_items(playlist_id=playlist_id, items=track_uris[i:i+100])

    print(f"✅ Playlist '{playlist_name}' created with {len(track_uris)} tracks.")

# %%
sample_track_id = 37938 
recommend_and_create_playlist(sample_track_id, num_recommendations=50)
# Out:
# ✅ Playlist 'Recommendations Based on HIGHEST IN THE ROOM' created with 50 tracks.
